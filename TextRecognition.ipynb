# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import codecs
import numpy as np

# %%
IMAGE_PATH = './images/tamiltext.png'
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
#1. Read in images or video
reader = easyocr.Reader(['ta'])
result = reader.readtext(IMAGE_PATH)
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[0, 0], [187, 0], [187, 15], [0, 15]], 'ஈித்தரிழ் சுரித்த சர்ச்ச சகள் அவ்பப்படாத்', 0.12748948559811302), ([[189, 1], [285, 1], [285, 13], [189, 13]], 'எ!ானதர் பாப பய்,', 0.07888406195677883), ([[0, 15], [119, 15], [119, 27], [0, 27]], 'பதாய் பந _ப 80~ச ~த்', 0.01998616241406624), ([[122, 18], [152, 18], [152, 26], [122, 26]], '5ா ாம', 0.19063999244045385), ([[156, 18], [182, 18], [182, 26], [156, 26]], '=51', 0.40153904486229697), ([[225, 13], [322, 13], [322, 27], [225, 27]], 'புத்தலவ் அ்மப', 0.10558067041063418), ([[25, 29], [73, 29], [73, 41], [25, 41]], 'பாா 5', 0.11481632622981568), ([[103, 29], [159, 29], [159, 41], [103, 41]], '|5=:சய#ே', 0.06291125835368747), ([[163, 29], [251, 29], [251, 43], [163, 43]], 'சரபக ;ருங்குரிசதச்', 0.1898464649659892), ([[0, 45], [87, 45], [87, 57], [0, 57]], 'நயர் எ 5்து5்க5', 0.04009613227315135), ([[92, 42], [131, 42], [131, 56], [92, 56]], 'சசர்ப்பது', 0.501306054678799), ([[133, 41], [269, 41], [269, 57], [133, 57]], 'தபழ் ஒடுங்குரிக்கள் ஏற்களம்ப', 0.21743076112603352), ([[0, 60], [26, 60], [26, 68], [0, 68]], '_பா5', 0.1751520037651062), ([[103, 59], [157, 59], [157, 71], [103, 71]], '=சபஎபன் 7', 0.11911439302151429), ([[170, 60], [200, 60], [200, 68], [170, 68]], 'வ0"', 0.012567429733524317), ([[204, 60], [244, 60], [244, 68], [204, 68]], '=|5! =1=', 0.16417669291636355), ([[248, 60], [308, 60], [308, 68], [248, 68]], 'ஏ17==5~எ5', 0.03744915013849738), ([[0, 70], [213, 70], [213, 87], [0, 87]], 'சேரப்பது தொடரபான பர்ந்தரைகள் தபழத் கலளீனி', 0.21227740810245402), ([[222, 74], [244, 74], [244, 82], [222, 82]], '^50', 0.03528892448465846), ([[246, 71], [287, 71], [287, 85], [246, 85]], 'கற்ச்டா =', 0.3420584157402718), ([[0, 87], [51, 87], [51, 99], [0, 99]], 'ர~7ாத :ப3.', 0.006511419857248891), ([[54, 88], [126, 88], [126, 96], [54, 96]], 'பப்ப ஈ    ', 0.005590897892068674), ([[131, 87], [293, 87], [293, 101], [131, 101]], 'எழய் கபிழ் =யிநர் ஈபர் பொழி்பட்ப', 0.16714296257178538), ([[43, 101], [103, 101], [103, 113], [43, 113]], '/சசப=நூ.சிச்ட', 0.0034258096486322743), ([[106, 104], [142, 104], [142, 112], [106, 112]], '=||!', 0.07172577828168869), ([[145, 101], [283, 101], [283, 115], [145, 115]], 'ஆர்ப்கர்ஈார் ஆயயோர் நந்தமத', 0.10298092692789111), ([[0, 118], [88, 118], [88, 126], [0, 126]], '5555=757 175', 0.02916853945945265), ([[105, 113], [313, 113], [313, 129], [105, 129]], 'விவாதிக்க அரசிய்வாதிகன் எிவாசத்தத் திசை', 0.24283685269360988), ([[1, 127], [277, 127], [277, 143], [1, 143]], 'சிருப்பிகபொண்டிரநக்கிரார்சன் =மிழக்கு அடாயம் என்ற ஒப்பாரிபும்', 0.13347612107347093), ([[183.39028923915032, 13.2073760108954], [224.9894610641341, 16.855200819882814], [223.60971076084968, 27.7926239891046], [182.0105389358659, 23.144799180117186]], 'வரவதம்', 0.13591795408283266), ([[68.18076807948096, 31.426537655636672], [99.92401683242188, 28.6176482072737], [100.81923192051904, 39.57346234436333], [69.07598316757812, 41.3823517927263]], ']78_', 0.16189219057559967), ([[0.18076807948095952, 101.42653765563666], [29.913811548620256, 99.59386153394655], [30.81923192051904, 109.57346234436334], [1.0861884513797428, 112.40613846605345]], '=154-1', 0.0417660735015376), ([[19.390289239150306, 142.2073760108954], [42.97014250014533, 145.75746437496366], [41.609710760849694, 156.7926239891046], [17.029857499854668, 152.24253562503634]], 'ற5', 0.7803096514448785)]

# %%
#2. Draw Results
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]


img = cv2.imread(IMAGE_PATH)
img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
img = cv2.putText(img,text,top_left, font, 0.5,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
#3. Handling Multiple Lines
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 3)
    img = cv2.putText(img, text, (20, spacer), font, 0.5, (0, 255, 0), 2, cv2.LINE_AA)
    print(text)
    spacer += 15

plt.imshow(img)
plt.show()
# Out:
# ஈித்தரிழ் சுரித்த சர்ச்ச சகள் அவ்பப்படாத்
# எ!ானதர் பாப பய்,
# பதாய் பந _ப 80~ச ~த்
# 5ா ாம
# =51
# புத்தலவ் அ்மப
# பாா 5
# |5=:சய#ே
# சரபக ;ருங்குரிசதச்
# நயர் எ 5்து5்க5
# சசர்ப்பது
# தபழ் ஒடுங்குரிக்கள் ஏற்களம்ப
# _பா5
# =சபஎபன் 7
# வ0"
# =|5! =1=
# ஏ17==5~எ5
# சேரப்பது தொடரபான பர்ந்தரைகள் தபழத் கலளீனி
# ^50
# கற்ச்டா =
# ர~7ாத :ப3.
# பப்ப ஈ
# எழய் கபிழ் =யிநர் ஈபர் பொழி்பட்ப
# /சசப=நூ.சிச்ட
# =||!
# ஆர்ப்கர்ஈார் ஆயயோர் நந்தமத
# 5555=757 175
# விவாதிக்க அரசிய்வாதிகன் எிவாசத்தத் திசை
# சிருப்பிகபொண்டிரநக்கிரார்சன் =மிழக்கு அடாயம் என்ற ஒப்பாரிபும்
# வரவதம்
# ]78_
# =154-1
# ற5
